# %% [markdown]
# Project #1

# %%
# Import 
import warnings
import pandas as pd
from pathlib import Path
#To ignore all warnings
warnings.filterwarnings('ignore')

# %%
# File Path
general_data_to_load = Path("Resources/Hospital_General_Information.csv")
score_data_to_load = Path("Resources/hvbp_tps.csv")

# Read School and Student Data File and store into Pandas DataFrames
general_data = pd.read_csv(general_data_to_load, encoding='latin1')
score_data = pd.read_csv(score_data_to_load)

# Combine the data from the files into a single dataset
hospital_data_complete = pd.merge(general_data, score_data, how="left", left_on='Provider ID', right_on="Facility ID")

# Make an output for the new dataset
output_file_path= 'hospital_data_complete.csv'
hospital_data_complete.to_csv(output_file_path, index=False)
hospital_data_complete=pd.read_csv(output_file_path)


hospital_data_complete
# Out:
#       Provider ID                     Hospital Name  \
# 0           10001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1           10005     MARSHALL MEDICAL CENTER SOUTH
# 2           10006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3           10007          MIZELL MEMORIAL HOSPITAL
# 4           10008       CRENSHAW COMMUNITY HOSPITAL
# ...           ...                               ...
# 4807       670118              FIRST TEXAS HOSPITAL
# 4808       640001       LBJ TROPICAL MEDICAL CENTER
# 4809       650001  GUAM MEMORIAL HOSPITAL AUTHORITY
# 4810       650003        GUAM REGIONAL MEDICAL CITY
# 4811       660001        COMMONWEALTH HEALTH CENTER
#
#                           Address_x       City State_x  ZIP Code_x  \
# 0            1108 ROSS CLARK CIRCLE     DOTHAN      AL       36301
# 1        2505 U S HIGHWAY 431 NORTH       BOAZ      AL       35957
# 2                205 MARENGO STREET   FLORENCE      AL       35631
# 3                     702 N MAIN ST        OPP      AL       36467
# 4               101 HOSPITAL CIRCLE    LUVERNE      AL       36049
# ...                             ...        ...     ...         ...
# 4807                9922 LOUETTA RD    HOUSTON      TX       77070
# 4808                FAGAALU VILLAGE  PAGO PAGO      AS       96799
# 4809  85O GOV CARLOS G CAMACHO ROAD   TAMUNING      GU       96913
# 4810                    133 ROUTE 3     DEDEDO      GU       96929
# 4811   PO BOX 409CK, NAVY HILL ROAD    GARAPAN      MP       96950
#
#      County Name  Phone Number         Hospital Type  \
# 0        HOUSTON    3347938701  Acute Care Hospitals
# 1       MARSHALL    2565938310  Acute Care Hospitals
# 2     LAUDERDALE    2567688400  Acute Care Hospitals
# 3      COVINGTON    3344933541  Acute Care Hospitals
# 4       CRENSHAW    3343353374  Acute Care Hospitals
# ...          ...           ...                   ...
# 4807      HARRIS    8442641435  Acute Care Hospitals
# 4808         NaN    6846334590  Acute Care Hospitals
# 4809         NaN    6716472552  Acute Care Hospitals
# 4810         NaN    6716455500  Acute Care Hospitals
# 4811         NaN    6702348950  Acute Care Hospitals
#
#                                Hospital Ownership  ... County/Parish  \
# 0     Government - Hospital District or Authority  ...       HOUSTON
# 1     Government - Hospital District or Authority  ...      MARSHALL
# 2     Government - Hospital District or Authority  ...    LAUDERDALE
# 3                  Voluntary non-profit - Private  ...     COVINGTON
# 4                                     Proprietary  ...           NaN
# ...                                           ...  ...           ...
# 4807                                  Proprietary  ...           NaN
# 4808  Government - Hospital District or Authority  ...           NaN
# 4809                           Government - Local  ...           NaN
# 4810               Voluntary non-profit - Private  ...           NaN
# 4811                                  Proprietary  ...           NaN
#
#      Unweighted Normalized Clinical Outcomes Domain Score  \
# 0                                           38.33333333
# 1                                                    28
# 2                                                     0
# 3                                           6.666666667
# 4                                                   NaN
# ...                                                 ...
# 4807                                                NaN
# 4808                                                NaN
# 4809                                                NaN
# 4810                                                NaN
# 4811                                                NaN
#
#      Weighted Normalized Clinical Outcomes Domain Score  \
# 0                                           9.583333333
# 1                                                     7
# 2                                                     0
# 3                                           2.222222222
# 4                                                   NaN
# ...                                                 ...
# 4807                                                NaN
# 4808                                                NaN
# 4809                                                NaN
# 4810                                                NaN
# 4811                                                NaN
#
#      Unweighted Person And Community Engagement Domain Score  \
# 0                                                    16
# 1                                                     6
# 2                                                     6
# 3                                                    24
# 4                                                   NaN
# ...                                                 ...
# 4807                                                NaN
# 4808                                                NaN
# 4809                                                NaN
# 4810                                                NaN
# 4811                                                NaN
#
#      Weighted Person And Community Engagement Domain Score  \
# 0                                                     4
# 1                                                   1.5
# 2                                                   1.5
# 3                                                     8
# 4                                                   NaN
# ...                                                 ...
# 4807                                                NaN
# 4808                                                NaN
# 4809                                                NaN
# 4810                                                NaN
# 4811                                                NaN
#
#      Unweighted Normalized Safety Domain Score Weighted Safety Domain Score  \
# 0                                            8                            2
# 1                                           22                          5.5
# 2                                           48                           12
# 3                                Not Available                Not Available
# 4                                          NaN                          NaN
# ...                                        ...                          ...
# 4807                                       NaN                          NaN
# 4808                                       NaN                          NaN
# 4809                                       NaN                          NaN
# 4810                                       NaN                          NaN
# 4811                                       NaN                          NaN
#
#      Unweighted Normalized Efficiency And Cost Reduction Domain Score  \
# 0                                                     0
# 1                                                    30
# 2                                                     0
# 3                                                    50
# 4                                                   NaN
# ...                                                 ...
# 4807                                                NaN
# 4808                                                NaN
# 4809                                                NaN
# 4810                                                NaN
# 4811                                                NaN
#
#      Weighted Efficiency And Cost Reduction Domain Score  \
# 0                                                     0
# 1                                                   7.5
# 2                                                     0
# 3                                           16.66666667
# 4                                                   NaN
# ...                                                 ...
# 4807                                                NaN
# 4808                                                NaN
# 4809                                                NaN
# 4810                                                NaN
# 4811                                                NaN
#
#      Total Performance Score
# 0                  15.583333
# 1                  21.500000
# 2                  13.500000
# 3                  26.888889
# 4                        NaN
# ...                      ...
# 4807                     NaN
# 4808                     NaN
# 4809                     NaN
# 4810                     NaN
# 4811                     NaN
#
# [4812 rows x 45 columns]

# %%
#Calculate the number of hospitals
hospital_unique_count=hospital_data_complete['Hospital Name'].nunique()
print("Number of unique hospitals:",hospital_unique_count)
print (hospital_data_complete.columns)
# Out:
# Number of unique hospitals: 4623
# Index(['Provider ID', 'Hospital Name', 'Address_x', 'City', 'State_x',
#        'ZIP Code_x', 'County Name', 'Phone Number', 'Hospital Type',
#        'Hospital Ownership', 'Emergency Services',
#        'Meets criteria for meaningful use of EHRs', 'Hospital overall rating',
#        'Hospital overall rating footnote', 'Mortality national comparison',
#        'Mortality national comparison footnote',
#        'Safety of care national comparison',
#        'Safety of care national comparison footnote',
#        'Readmission national comparison',
#        'Readmission national comparison footnote',
#        'Patient experience national comparison',
#        'Patient experience national comparison footnote',
#        'Effectiveness of care national comparison',
#        'Effectiveness of care national comparison footnote',
#        'Timeliness of care national comparison',
#        'Timeliness of care national comparison footnote',
#        'Efficient use of medical imaging national comparison',
#        'Efficient use of medical imaging national comparison footnote',
#        'Fiscal Year', 'Facility ID', 'Facility Name', 'Address_y', 'City/Town',
#        'State_y', 'ZIP Code_y', 'County/Parish',
#        'Unweighted Normalized Clinical Outcomes Domain Score',
#        'Weighted Normalized Clinical Outcomes Domain Score',
#        'Unweighted Person And Community Engagement Domain Score',
#        'Weighted Person And Community Engagement Domain Score',
#        'Unweighted Normalized Safety Domain Score',
#        'Weighted Safety Domain Score',
#        'Unweighted Normalized Efficiency And Cost Reduction Domain Score',
#        'Weighted Efficiency And Cost Reduction Domain Score',
#        'Total Performance Score'],
#       dtype='object')

# %%
#del hospital_data_complete['Facility Name'] #,['Address_y'], ['City/Town'],
       #['State_y'], ['ZIP Code_y'], ['County/Parish']

# Drop all rows with missing information
#hospital_data_complete = hospital_data_complete.dropna(how='any')
#hospital_data_complete
# Identify incomplete rows
hospital_data_complete.count()
# Out:
# Provider ID                                                         4812
# Hospital Name                                                       4812
# Address_x                                                           4812
# City                                                                4812
# State_x                                                             4812
# ZIP Code_x                                                          4812
# County Name                                                         4797
# Phone Number                                                        4812
# Hospital Type                                                       4812
# Hospital Ownership                                                  4812
# Emergency Services                                                  4812
# Meets criteria for meaningful use of EHRs                           4669
# Hospital overall rating                                             4812
# Hospital overall rating footnote                                    1398
# Mortality national comparison                                       4812
# Mortality national comparison footnote                              1352
# Safety of care national comparison                                  4812
# Safety of care national comparison footnote                         2168
# Readmission national comparison                                     4812
# Readmission national comparison footnote                            1017
# Patient experience national comparison                              4812
# Patient experience national comparison footnote                     1369
# Effectiveness of care national comparison                           4812
# Effectiveness of care national comparison footnote                  1202
# Timeliness of care national comparison                              4812
# Timeliness of care national comparison footnote                     1266
# Efficient use of medical imaging national comparison                4812
# Efficient use of medical imaging national comparison footnote       2033
# Fiscal Year                                                         2453
# Facility ID                                                         2453
# Facility Name                                                       2453
# Address_y                                                           2453
# City/Town                                                           2453
# State_y                                                             2453
# ZIP Code_y                                                          2453
# County/Parish                                                       2453
# Unweighted Normalized Clinical Outcomes Domain Score                2453
# Weighted Normalized Clinical Outcomes Domain Score                  2453
# Unweighted Person And Community Engagement Domain Score             2453
# Weighted Person And Community Engagement Domain Score               2453
# Unweighted Normalized Safety Domain Score                           2453
# Weighted Safety Domain Score                                        2453
# Unweighted Normalized Efficiency And Cost Reduction Domain Score    2453
# Weighted Efficiency And Cost Reduction Domain Score                 2453
# Total Performance Score                                             2453
# dtype: int64

# %%
hospital_data_df = pd.DataFrame({
    'Provider ID': hospital_data_complete['Provider ID'],
    'Hospital Name': hospital_data_complete['Hospital Name'],
    'Address': hospital_data_complete['Address_x'],  # Renamed to 'Address'
    'City': hospital_data_complete['City'],
    'State': hospital_data_complete['State_x'],      # Renamed to 'State'
    'ZIP Code': hospital_data_complete['ZIP Code_x'],# Renamed to 'Zip Code'
    'County Name': hospital_data_complete['County Name'],
    'Phone Number': hospital_data_complete['Phone Number'],
    'Hospital Type': hospital_data_complete['Hospital Type'],
    'Hospital Ownership': hospital_data_complete['Hospital Ownership'],
    'Emergency Services': hospital_data_complete['Emergency Services'],
    'Meets criteria for meaningful use of EHRs': hospital_data_complete['Meets criteria for meaningful use of EHRs'],
    'Hospital overall rating': hospital_data_complete['Hospital overall rating'],
    'Weighted Normalized Clinical Outcomes Domain Score': hospital_data_complete['Weighted Normalized Clinical Outcomes Domain Score'],
    'Weighted Person And Community Engagement Domain Score': hospital_data_complete['Weighted Person And Community Engagement Domain Score'],
    'Weighted Safety Domain Score': hospital_data_complete['Weighted Safety Domain Score'],
    'Weighted Efficiency And Cost Reduction Domain Score': hospital_data_complete['Weighted Efficiency And Cost Reduction Domain Score'],
    'Total Performance Score': hospital_data_complete['Total Performance Score']
})

hospital_data_df
# Out:
#       Provider ID                     Hospital Name  \
# 0           10001  SOUTHEAST ALABAMA MEDICAL CENTER
# 1           10005     MARSHALL MEDICAL CENTER SOUTH
# 2           10006    ELIZA COFFEE MEMORIAL HOSPITAL
# 3           10007          MIZELL MEMORIAL HOSPITAL
# 4           10008       CRENSHAW COMMUNITY HOSPITAL
# ...           ...                               ...
# 4807       670118              FIRST TEXAS HOSPITAL
# 4808       640001       LBJ TROPICAL MEDICAL CENTER
# 4809       650001  GUAM MEMORIAL HOSPITAL AUTHORITY
# 4810       650003        GUAM REGIONAL MEDICAL CITY
# 4811       660001        COMMONWEALTH HEALTH CENTER
#
#                             Address       City State  ZIP Code County Name  \
# 0            1108 ROSS CLARK CIRCLE     DOTHAN    AL     36301     HOUSTON
# 1        2505 U S HIGHWAY 431 NORTH       BOAZ    AL     35957    MARSHALL
# 2                205 MARENGO STREET   FLORENCE    AL     35631  LAUDERDALE
# 3                     702 N MAIN ST        OPP    AL     36467   COVINGTON
# 4               101 HOSPITAL CIRCLE    LUVERNE    AL     36049    CRENSHAW
# ...                             ...        ...   ...       ...         ...
# 4807                9922 LOUETTA RD    HOUSTON    TX     77070      HARRIS
# 4808                FAGAALU VILLAGE  PAGO PAGO    AS     96799         NaN
# 4809  85O GOV CARLOS G CAMACHO ROAD   TAMUNING    GU     96913         NaN
# 4810                    133 ROUTE 3     DEDEDO    GU     96929         NaN
# 4811   PO BOX 409CK, NAVY HILL ROAD    GARAPAN    MP     96950         NaN
#
#       Phone Number         Hospital Type  \
# 0       3347938701  Acute Care Hospitals
# 1       2565938310  Acute Care Hospitals
# 2       2567688400  Acute Care Hospitals
# 3       3344933541  Acute Care Hospitals
# 4       3343353374  Acute Care Hospitals
# ...            ...                   ...
# 4807    8442641435  Acute Care Hospitals
# 4808    6846334590  Acute Care Hospitals
# 4809    6716472552  Acute Care Hospitals
# 4810    6716455500  Acute Care Hospitals
# 4811    6702348950  Acute Care Hospitals
#
#                                Hospital Ownership Emergency Services  \
# 0     Government - Hospital District or Authority                Yes
# 1     Government - Hospital District or Authority                Yes
# 2     Government - Hospital District or Authority                Yes
# 3                  Voluntary non-profit - Private                Yes
# 4                                     Proprietary                Yes
# ...                                           ...                ...
# 4807                                  Proprietary                Yes
# 4808  Government - Hospital District or Authority                Yes
# 4809                           Government - Local                Yes
# 4810               Voluntary non-profit - Private                Yes
# 4811                                  Proprietary                Yes
#
#      Meets criteria for meaningful use of EHRs Hospital overall rating  \
# 0                                            Y                       3
# 1                                            Y                       3
# 2                                            Y                       2
# 3                                            Y                       2
# 4                                            Y                       3
# ...                                        ...                     ...
# 4807                                       NaN           Not Available
# 4808                                         Y           Not Available
# 4809                                         Y                       3
# 4810                                       NaN           Not Available
# 4811                                         Y           Not Available
#
#      Weighted Normalized Clinical Outcomes Domain Score  \
# 0                                           9.583333333
# 1                                                     7
# 2                                                     0
# 3                                           2.222222222
# 4                                                   NaN
# ...                                                 ...
# 4807                                                NaN
# 4808                                                NaN
# 4809                                                NaN
# 4810                                                NaN
# 4811                                                NaN
#
#      Weighted Person And Community Engagement Domain Score  \
# 0                                                     4
# 1                                                   1.5
# 2                                                   1.5
# 3                                                     8
# 4                                                   NaN
# ...                                                 ...
# 4807                                                NaN
# 4808                                                NaN
# 4809                                                NaN
# 4810                                                NaN
# 4811                                                NaN
#
#      Weighted Safety Domain Score  \
# 0                               2
# 1                             5.5
# 2                              12
# 3                   Not Available
# 4                             NaN
# ...                           ...
# 4807                          NaN
# 4808                          NaN
# 4809                          NaN
# 4810                          NaN
# 4811                          NaN
#
#      Weighted Efficiency And Cost Reduction Domain Score  \
# 0                                                     0
# 1                                                   7.5
# 2                                                     0
# 3                                           16.66666667
# 4                                                   NaN
# ...                                                 ...
# 4807                                                NaN
# 4808                                                NaN
# 4809                                                NaN
# 4810                                                NaN
# 4811                                                NaN
#
#       Total Performance Score
# 0                   15.583333
# 1                   21.500000
# 2                   13.500000
# 3                   26.888889
# 4                         NaN
# ...                       ...
# 4807                      NaN
# 4808                      NaN
# 4809                      NaN
# 4810                      NaN
# 4811                      NaN
#
# [4812 rows x 18 columns]

# %%
# Drop all rows with missing information
# First, drop rows with any NaN values
hospital_data_df = hospital_data_df.dropna(how='any')

# Then, drop rows where 'Not Available' is present in any column
hospital_data_df = hospital_data_df[~hospital_data_df.isin(['Not Available']).any(axis=1)]
hospital_data_df
# Out:
#       Provider ID                                      Hospital Name  \
# 0           10001                   SOUTHEAST ALABAMA MEDICAL CENTER
# 1           10005                      MARSHALL MEDICAL CENTER SOUTH
# 2           10006                     ELIZA COFFEE MEMORIAL HOSPITAL
# 5           10011                                  ST VINCENT'S EAST
# 6           10012                     DEKALB REGIONAL MEDICAL CENTER
# ...           ...                                                ...
# 4779       670080                SETON MEDICAL CENTER HARKER HEIGHTS
# 4780       670082   BAYLOR SCOTT AND WHITE  MEDICAL CENTER  MCKINNEY
# 4782       670085    TEXAS HEALTH HARRIS METHODIST HOSPITAL ALLIANCE
# 4784       670088  BAYLOR SCOTT & WHITE MEDICAL CENTER- COLLEGE S...
# 4793       670098                           RESOLUTE HEALTH HOSPITAL
#
#                              Address             City State  ZIP Code  \
# 0             1108 ROSS CLARK CIRCLE           DOTHAN    AL     36301
# 1         2505 U S HIGHWAY 431 NORTH             BOAZ    AL     35957
# 2                 205 MARENGO STREET         FLORENCE    AL     35631
# 5         50 MEDICAL PARK EAST DRIVE       BIRMINGHAM    AL     35235
# 6               200 MED CENTER DRIVE       FORT PAYNE    AL     35968
# ...                              ...              ...   ...       ...
# 4779  850 W CENTRAL TEXAS EXPRESSWAY   HARKER HEIGHTS    TX     76548
# 4780      5252 WEST UNIVERSITY DRIVE        MC KINNEY    TX     75071
# 4782        10864 TEXAS HEALTH TRAIL       FORT WORTH    TX     76244
# 4784         700 SCOTT & WHITE DRIVE  COLLEGE STATION    TX     77845
# 4793             555 CREEKSIDE XING,    NEW BRAUNFELS    TX     78130
#
#      County Name  Phone Number         Hospital Type  \
# 0        HOUSTON    3347938701  Acute Care Hospitals
# 1       MARSHALL    2565938310  Acute Care Hospitals
# 2     LAUDERDALE    2567688400  Acute Care Hospitals
# 5      JEFFERSON    2058383122  Acute Care Hospitals
# 6        DE KALB    2568453150  Acute Care Hospitals
# ...          ...           ...                   ...
# 4779        BELL    2549538342  Acute Care Hospitals
# 4780      COLLIN    4697642200  Acute Care Hospitals
# 4782     TARRANT    6822122000  Acute Care Hospitals
# 4784      BRAZOS    9796913701  Acute Care Hospitals
# 4793       COMAL    4698396778  Acute Care Hospitals
#
#                                Hospital Ownership Emergency Services  \
# 0     Government - Hospital District or Authority                Yes
# 1     Government - Hospital District or Authority                Yes
# 2     Government - Hospital District or Authority                Yes
# 5                  Voluntary non-profit - Private                Yes
# 6                                     Proprietary                Yes
# ...                                           ...                ...
# 4779                                  Proprietary                Yes
# 4780               Voluntary non-profit - Private                Yes
# 4782               Voluntary non-profit - Private                Yes
# 4784               Voluntary non-profit - Private                Yes
# 4793                                  Proprietary                Yes
#
#      Meets criteria for meaningful use of EHRs Hospital overall rating  \
# 0                                            Y                       3
# 1                                            Y                       3
# 2                                            Y                       2
# 5                                            Y                       2
# 6                                            Y                       3
# ...                                        ...                     ...
# 4779                                         Y                       4
# 4780                                         Y                       4
# 4782                                         Y                       4
# 4784                                         Y                       4
# 4793                                         Y                       3
#
#      Weighted Normalized Clinical Outcomes Domain Score  \
# 0                                           9.583333333
# 1                                                     7
# 2                                                     0
# 5                                                  3.75
# 6                                                 3.125
# ...                                                 ...
# 4779                                                2.5
# 4780                                                9.5
# 4782                                              1.875
# 4784                                        4.583333333
# 4793                                                  5
#
#      Weighted Person And Community Engagement Domain Score  \
# 0                                                     4
# 1                                                   1.5
# 2                                                   1.5
# 5                                                     4
# 6                                                   3.5
# ...                                                 ...
# 4779                                                6.5
# 4780                                               5.75
# 4782                                                  4
# 4784                                                  9
# 4793                                               3.75
#
#      Weighted Safety Domain Score  \
# 0                               2
# 1                             5.5
# 2                              12
# 5                               4
# 6                            17.5
# ...                           ...
# 4779                         12.5
# 4780                         11.5
# 4782                         21.5
# 4784                            7
# 4793                           10
#
#      Weighted Efficiency And Cost Reduction Domain Score  \
# 0                                                     0
# 1                                                   7.5
# 2                                                     0
# 5                                                   2.5
# 6                                                     0
# ...                                                 ...
# 4779                                                  0
# 4780                                                2.5
# 4782                                                  0
# 4784                                                2.5
# 4793                                                2.5
#
#       Total Performance Score
# 0                   15.583333
# 1                   21.500000
# 2                   13.500000
# 5                   14.250000
# 6                   24.125000
# ...                       ...
# 4779                21.500000
# 4780                29.250000
# 4782                27.375000
# 4784                23.083333
# 4793                21.250000
#
# [2017 rows x 18 columns]
